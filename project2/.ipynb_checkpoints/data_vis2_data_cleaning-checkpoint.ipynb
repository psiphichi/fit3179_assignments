# %%
import pandas as pd

# %%
df = pd.read_csv('international_financial_statistics_data.csv')
df
# Out:
#                   oid country_or_area  year                      description  \
# 0       79976ECZZF...     AFRICA N.S.  2009                    COFFEE:UGANDA
# 1       79976ECDZF...     AFRICA N.S.  2009         COFFEE UGANDA (NEW YORK)
# 2       79976ECZZF...     AFRICA N.S.  2008                    COFFEE:UGANDA
# 3       79976ECDZF...     AFRICA N.S.  2008         COFFEE UGANDA (NEW YORK)
# 4       79976ECZZF...     AFRICA N.S.  2007                    COFFEE:UGANDA
# ...               ...             ...   ...                              ...
# 884239  69862...ZF...        ZIMBABWE  1979  SHARE PRICE INDEX (INDUSTRIALS)
# 884240  69862...ZF...        ZIMBABWE  1978  SHARE PRICE INDEX (INDUSTRIALS)
# 884241  69862...ZF...        ZIMBABWE  1977  SHARE PRICE INDEX (INDUSTRIALS)
# 884242  69862...ZF...        ZIMBABWE  1976  SHARE PRICE INDEX (INDUSTRIALS)
# 884243  69862...ZF...        ZIMBABWE  1975  SHARE PRICE INDEX (INDUSTRIALS)
#
# ...

# %%
print(df['country_or_area'].unique())
# Out:
# ['AFRICA N.S.' 'ALGERIA' 'AUSTRALIA' 'AUSTRIA' 'BANGLADESH' 'BELGIUM'
#  'BRAZIL' 'CANADA' 'CHILE' 'COLOMBIA' 'DENMARK' 'DJIBOUTI' 'EAST AFRICA'
#  'ECUADOR' 'EMER.& DEVELOP. ECO.' 'FINLAND' 'FRANCE' 'GERMANY' 'GHANA'
#  'GREECE' 'HUNGARY' 'INDONESIA' 'IRAN, I.R. OF' 'JAPAN'
#  'KOREA, REPUBLIC OF' 'MALAYSIA' 'MAURITIUS' 'MOROCCO' 'NEW ZEALAND'
#  'NIGERIA' 'NORWAY' 'OMAN' 'OTH CENT AMERICA NS' 'PERU' 'PHILIPPINES'
#  'POLAND' 'PORTUGAL' 'RUSSIAN FEDERATION' 'SAUDI ARABIA' 'SINGAPORE'
#  'SOUTH AFRICA' 'SPAIN' 'ST. LUCIA' 'SWEDEN' 'SWITZERLAND' 'THAILAND'
#  'UKRAINE' 'UNITED ARAB EMIRATES' 'UNITED KINGDOM' 'UNITED STATES'
#  'VENEZUELA, REP. BOL.' 'WORLD' 'ADVANCED ECONOMIES'
#  'AFGHANISTAN, I.R. OF' 'AFRICA' 'ALBANIA' 'AMERICAN SAMOA' 'ANGOLA'
#  'ANGUILLA' 'ANTIGUA AND BARBUDA' 'APEC' 'ARGENTINA' 'ARMENIA' 'ARUBA'
#  'AZERBAIJAN, REP. OF' 'BAHAMAS, THE' 'BAHRAIN, KINGDOM OF' 'BARBADOS'
#  'BELARUS' 'BELGIUM-LUXEMBOURG' 'BELIZE' 'BENIN' 'BERMUDA' 'BHUTAN'
# ...
